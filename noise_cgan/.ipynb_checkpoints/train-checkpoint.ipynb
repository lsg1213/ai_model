# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (0.7.2)
# Requirement already satisfied: audioread>=2.0.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (2.1.8)
# Requirement already satisfied: joblib>=0.12 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (0.14.1)
# Requirement already satisfied: numpy>=1.15.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (1.18.4)
# Requirement already satisfied: six>=1.3 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (1.14.0)
# Requirement already satisfied: scipy>=1.0.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (1.4.1)
# Requirement already satisfied: numba>=0.43.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (0.49.1)
# Requirement already satisfied: soundfile>=0.9.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: decorator>=3.0.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: resampy>=0.2.2 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: llvmlite<=0.33.0.dev0,>=0.31.0.dev0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from numba>=0.43.0->librosa) (0.32.1)
# Requirement already satisfied: setuptools in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from numba>=0.43.0->librosa) (46.1.3.post20200330)
# Requirement already satisfied: cffi>=1.0 in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from soundfile>=0.9.0->librosa) (1.14.0)
# Requirement already satisfied: pycparser in /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge librosa ffmpeg
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# IPython.display for audio output
import IPython.display as ipd
from tensorflow.keras.layers import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Model, Sequential
import keras.backend as K
import tensorflow as tf

# Librosa for audio
import librosa
# And the display module for visualization
import librosa.display
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /root/anaconda3/envs/ten2.1/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# Using TensorFlow backend.

# %%
audio_path = '/root/datasets/ai_challenge/SoundIdea/SoundIdea/6000/'
generate_path = './generated_noise/'
feature = 'stft'
if not( feature in ('stft')):
    raise ValueError('wrong feature')
dir = np.array(os.listdir(audio_path))
train_label = [i for i,j in np.char.split(dir, sep=' ')]
label_list = sorted(list(set(train_label)))
for i in range(len(train_label)):
    train_label[i] = label_list.index(train_label[i])
resample_sr = 16000
length = 2 # seconds
noise_dim = 300
class_num = len(label_list)
BATCH_SIZE = 32
EPOCHS = 100

# %%
resampled_data, sr = [], []
import time
start_time = time.time()

step = 0
for k,i in enumerate(dir):
    _audio_data, _sr = librosa.load(audio_path+i, sr=None)
    if _audio_data.shape[0] / _sr < length:
        t = (length * _sr - _audio_data.shape[0])
        _audio_data = np.pad(_audio_data, (t//2, t - (t//2)), 'constant', constant_values=(0))
        if _audio_data.shape[0] != length * _sr:
            raise ValueError('something wrong with doing pad')
    elif _audio_data.shape[0] / _sr > length:
        _audio_data = _audio_data[:length * _sr]
    resampled_data.append(librosa.resample(_audio_data, _sr, resample_sr) if _sr != resample_sr else _audio_data)
    sr.append(_sr)
    if step % 100 == 0:
        print(f'{step}/{dir.shape[0]}')
    step += 1
print(f'complete {time.time() - start_time} seconds')
resampled_data = np.array(resampled_data)
# Out:
# 0/7546
# 100/7546
# 200/7546
# 300/7546
# 400/7546
# 500/7546

# %%
shape = None
if feature == 'stft':
    shape = librosa.stft(resampled_data[0]).shape
elif feature == 'mel':
    shape = librosa.feature.melspectrogram(resampled_data[0]).shape
else:
    raise ValueError('wrong feature')

# %%
ipd.Audio(audio_path+dir[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def build_generator(output_shape=shape, class_num=class_num, stddev=0.2, z_dim=noise_dim):
    model = Sequential()

    model.add(Dense(256, input_dim=z_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(np.prod(output_shape), activation='tanh'))
    model.add(Reshape(output_shape))

    noise = Input(shape=(z_dim,))
    label = Input(shape=(1,), dtype='int32')
    label_embedding = Flatten()(Embedding(class_num, z_dim)(label))

    model_input = multiply([noise, label_embedding])
    img = model(model_input)

    return Model([noise, label], img)

    



def build_discriminator(input_shape=shape, class_num=class_num, stddev=0.2):
    noise_input = Input(shape=input_shape)
    reshaped_noise = Flatten()(noise_input)

    model = Sequential()

    model.add(Dense(512, input_dim=np.prod(input_shape)))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))

    img = Input(shape=input_shape)
    label = Input(shape=(1,), dtype='int32')

    label_embedding = Flatten()(Embedding(class_num, np.prod(input_shape))(label))
    flat_img = Flatten()(img)

    model_input = multiply([flat_img, label_embedding])

    validity = model(model_input)

    return Model([img, label], validity)

  
def train(dataset, epochs):
    for epoch in range(epochs):
        start = time.time()
        d_loss_real = [0,0]
        d_loss_fake = [0,0]
        g_loss = 0
        step = 0

        for noise_batch, label_batch in dataset:
#             noise_batch = tf.cast(noise_batch, tf.float32)

            noise = np.random.normal(0, 1, (noise_batch.shape[0], noise_dim))
            # labels = tf.one_hot(labels,10)
            label_batch = tf.reshape(label_batch,(noise_batch.shape[0], -1))
            generated_noise = generator.predict([noise,label_batch])

            valid = np.ones((noise_batch.shape[0], 1))
            fake = np.zeros((noise_batch.shape[0], 1))

            d_loss_real = np.add(d_loss_real, discriminator.train_on_batch([noise_batch, label_batch], valid))
            d_loss_fake = np.add(d_loss_fake, discriminator.train_on_batch([generated_noise, label_batch], fake))
            sampled_labels = np.random.randint(0, class_num, noise_batch.shape[0])
            g_loss = np.add(g_loss, combined.train_on_batch([noise, sampled_labels], valid))
            step += 1
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0]/step, 100*d_loss[1]/step, g_loss/step))


        # GIF를 위한 이미지를 바로 생성합니다.
        # generate_and_save_noises(generator,
        #                             epoch + 1,
        #                             seed)
        sample_noises(generator, epoch+1)

        # 5 에포크가 지날 때마다 모델을 저장합니다.
        if (epoch + 1) % 5 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)

        # print (' 에포크 {} 에서 걸린 시간은 {} 초 입니다'.format(epoch +1, time.time()-start))
        print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

    sample_noises(generator, epochs)
    
def preprocessing(data):
    train_data = []
    if feature == 'stft':
        for i in range(len(data)):
            train_data.append(librosa.stft(data[i]))
    return np.array(train_data)

# %%
def sample_noises(generator, epoch):
    r, c = 2, 5
    noise = np.random.normal(0, 1, (r * c, noise_dim))
    sampled_labels = np.arange(0, 10).reshape(-1, 1)

    gen_sound = generator.predict([noise, sampled_labels])
    sampled_labels = np.arange(0, 10).reshape(-1)
    for i, j in enumerate(sampled_labels):
        librosa.output.write_wav(os.path.join(generate_path, f'{epoch}_{label_list[j]}.wav'), librosa.istft(gen_sound[i]), resample_sr, norm=True)

# %%
train_data = preprocessing(resampled_data)

# %%
generator = build_generator()
discriminator = build_discriminator()

generator_optimizer = tf.keras.optimizers.Adam(0.001, 0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(0.0001, 0.5)
discriminator.compile(loss=['binary_crossentropy'],
        optimizer=discriminator_optimizer,
        metrics=['acc'])
noise = Input(shape=(noise_dim,))
label = Input(shape=(1,))
sound = generator([noise, label])
discriminator.trainable = False
valid = discriminator([sound, label])
combined = Model([noise, label], valid)
combined.compile(loss=['binary_crossentropy'],
        optimizer=generator_optimizer)

checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                discriminator_optimizer=discriminator_optimizer,
                                generator=generator,
                                discriminator=discriminator)

# %%
perm = np.random.permutation(len(train_data))
train_noises = np.array(train_data)[perm]
train_labels = np.array(train_label)[perm]

train_dataset = tf.data.Dataset.from_tensor_slices((train_noises, train_labels)).batch(BATCH_SIZE)
train(train_dataset, EPOCHS)
# Out:
# 0 [D loss: 0.613990, acc.: 61.10%] [G loss: 0.763347]
# Time for epoch 1 is 396.5916986465454 sec
# 1 [D loss: 0.460029, acc.: 74.51%] [G loss: 1.242797]
# Time for epoch 2 is 391.90237402915955 sec
# 2 [D loss: 0.337881, acc.: 84.17%] [G loss: 1.730204]
# Time for epoch 3 is 396.8238639831543 sec
# 3 [D loss: 0.224722, acc.: 88.37%] [G loss: 2.946618]
# Time for epoch 4 is 390.755220413208 sec
# 4 [D loss: 0.154692, acc.: 90.60%] [G loss: 4.441458]
# Time for epoch 5 is 405.6500120162964 sec
# 5 [D loss: 0.125104, acc.: 91.90%] [G loss: 5.897557]
# Time for epoch 6 is 385.5833806991577 sec
# 6 [D loss: 0.108914, acc.: 93.73%] [G loss: 6.715138]
# Time for epoch 7 is 382.00329875946045 sec
# 7 [D loss: 0.097013, acc.: 96.27%] [G loss: 7.815408]
# Time for epoch 8 is 386.90785694122314 sec
# 8 [D loss: 0.081580, acc.: 97.60%] [G loss: 8.346610]
# Time for epoch 9 is 385.5289077758789 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-7a1e369bb223> in <module>
#       4
#       5 train_dataset = tf.data.Dataset.from_tensor_slices((train_noises, train_labels)).batch(BATCH_SIZE)
# ----> 6 train(train_dataset, EPOCHS)
#
# <ipython-input-26-e478b141f9ee> in train(dataset, epochs)
#      76
#      77             d_loss_real = np.add(d_loss_real, discriminator.train_on_batch([noise_batch, label_batch], valid))
# ---> 78             d_loss_fake = np.add(d_loss_fake, discriminator.train_on_batch([generated_noise, label_batch], fake))
#      79             sampled_labels = np.random.randint(0, class_num, noise_batch.shape[0])
#      80             g_loss = np.add(g_loss, combined.train_on_batch([noise, sampled_labels], valid))
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1076           self, x, y=y, sample_weight=sample_weight,
#    1077           class_weight=class_weight, reset_metrics=reset_metrics,
# -> 1078           standalone=True)
#    1079       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#    1080                  outputs['metrics'])
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics, standalone)
#     431       y,
#     432       sample_weights=sample_weights,
# --> 433       output_loss_metrics=model._output_loss_metrics)
#     434
#     435   if reset_metrics:
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/ten2.1/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
sample_noises(generator, 16)

# %%
generator.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 100)       92100       input_9[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 100)          0           embedding_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 100)          0           input_8[0][0]
#                                                                  flatten_4[0][0]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 1025, 63)     66879295    multiply_2[0][0]
# ==================================================================================================
# Total params: 66,971,395
# Trainable params: 66,967,811
# Non-trainable params: 3,584
# __________________________________________________________________________________________________

# %%
path = './generated_noise'
os.listdir(path)
# Out:
# ['8_AirplaneSingleProp',
#  '12_AircraftCarrier',
#  '15_AirplaneCabin',
#  '13_AirplaneCabin',
#  '7_AirRelease.wav',
#  '5_AirplaneBiplane.wav',
#  '1_AircraftCarrier',
#  '9_AirplaneSingleProp',
#  '9_AirRelease',
#  '2_AirConditioner',
#  '4_AirplaneCabin.wav',
#  '6_AirplaneCabin.wav',
#  '2_AirplaneSingleProp.wav',
#  '17_AirRelease',
#  '15_AirplaneBiplane.wav',
#  '7_AirRelease',
#  '17_AirConditioner',
#  '7_AircraftCarrier.wav',
#  '13_AirConditioner',
#  '7_AirplaneCockpit.wav',
#  '6_AirplaneBiplane.wav',
#  '3_AirConditioner.wav',
#  '5_AirplaneJet',
#  '10_AddingMachine',
#  '16_AirplaneCockpit',
#  '3_AirRelease',
#  '6_AircraftCarrier',
#  '1_AirConditioner',
#  '15_AddingMachine',
#  '16_AirplaneJet',
#  '13_AirplaneCockpit',
#  '9_AirplaneCabin',
#  '4_AirplaneJet',
#  '14_AddingMachine',
#  '2_AirplaneSingleProp',
#  '15_AirplaneSingleProp',
#  '7_AirplaneSingleProp',
#  '6_AirplaneBiplane',
#  '4_AirplaneCabin',
#  '11_AircraftCarrier',
#  '9_AirConditioner',
#  '15_AirRegulator.wav',
#  '4_AddingMachine',
#  '15_AirplaneJet',
#  '16_AirRegulator.wav',
#  '16_AircraftCarrier.wav',
#  '9_AircraftCarrier.wav',
#  '4_AircraftCarrier.wav',
#  '2_AirplaneCabin.wav',
#  '4_AirRelease.wav',
#  '5_AirplaneSingleProp',
#  '8_AddingMachine',
#  '7_AircraftCarrier',
#  '7_AirplaneCabin',
#  '12_AirplaneCockpit',
#  '8_AircraftCarrier',
#  '9_AirRegulator.wav',
#  '9_AddingMachine',
#  '8_AirConditioner',
#  '7_AirplaneCabin.wav',
#  '3_AirplaneJet.wav',
#  '4_AirplaneJet.wav',
#  '9_AircraftCarrier',
#  '7_AirRegulator.wav',
#  '8_AirRegulator.wav',
#  '14_AirplaneCockpit',
#  '9_AirplaneJet',
#  '4_AddingMachine.wav',
#  '14_AirRelease',
#  '2_AddingMachine.wav',
#  '3_AirplaneBiplane.wav',
#  '16_AirplaneCabin.wav',
#  '15_AirplaneSingleProp.wav',
#  '13_AddingMachine',
#  '6_AirRegulator.wav',
#  '7_AirRegulator',
#  '8_AirplaneJet.wav',
#  '9_AirplaneBiplane.wav',
#  '2_AirplaneBiplane',
#  '11_AirplaneJet',
#  '15_AirConditioner',
#  '3_AddingMachine.wav',
#  '5_AirplaneCabin',
#  '1_AirRelease.wav',
#  '11_AirplaneCockpit',
#  '3_AirRelease.wav',
#  '16_AirplaneJet.wav',
#  '3_AirConditioner',
#  '10_AirplaneBiplane',
#  '3_AirplaneBiplane',
#  '16_AirRegulator',
#  '1_AirplaneJet',
#  '15_AirplaneCabin.wav',
#  '3_AirplaneCabin',
#  '15_AirRelease.wav',
#  '4_AirRelease',
#  '9_AirplaneCockpit.wav',
#  '9_AirplaneCabin.wav',
#  '1_AddingMachine',
#  '9_AirRegulator',
#  '10_AirplaneSingleProp',
#  '4_AirRegulator.wav',
#  '2_AirConditioner.wav',
#  '15_AircraftCarrier',
#  '16_AircraftCarrier',
#  '6_AddingMachine',
#  '12_AirRegulator',
#  '7_AirplaneSingleProp.wav',
#  '2_AirRelease.wav',
#  '11_AirplaneBiplane',
#  '3_AirplaneCockpit',
#  '12_AirplaneBiplane',
#  '2_AircraftCarrier',
#  '1_AirplaneSingleProp',
#  '6_AirplaneCockpit',
#  '15_AirRelease',
#  '1_AirplaneJet.wav',
#  '17_AircraftCarrier',
#  '8_AirplaneCabin.wav',
#  '3_AircraftCarrier',
#  '15_AddingMachine.wav',
#  '14_AirplaneSingleProp',
#  '17_AirplaneSingleProp',
#  '14_AirplaneCabin',
#  '9_AddingMachine.wav',
#  '17_AddingMachine',
#  '1_AirplaneCabin.wav',
#  '3_AircraftCarrier.wav',
#  '10_AirRelease',
#  '6_AirConditioner.wav',
#  '8_AirRelease.wav',
#  '17_AirplaneJet',
#  '14_AircraftCarrier',
#  '3_AirplaneCockpit.wav',
#  '6_AirRegulator',
#  '4_AirplaneBiplane.wav',
#  '5_AirplaneCockpit',
#  '9_AirplaneCockpit',
#  '8_AircraftCarrier.wav',
#  '14_AirplaneJet',
#  '17_AirplaneBiplane',
#  '1_AirplaneCockpit.wav',
#  '1_AddingMachine.wav',
#  '10_AirRegulator',
#  '5_AirplaneSingleProp.wav',
#  '2_AircraftCarrier.wav',
#  '15_AirConditioner.wav',
#  '4_AirplaneCockpit',
#  '15_AirRegulator',
#  '2_AirplaneBiplane.wav',
#  '3_AirplaneCabin.wav',
#  '4_AircraftCarrier',
#  '5_AddingMachine',
#  '14_AirplaneBiplane',
#  '6_AirRelease',
#  '1_AirplaneBiplane',
#  '5_AircraftCarrier.wav',
#  '2_AirplaneJet',
#  '7_AddingMachine.wav',
#  '6_AirplaneSingleProp',
#  '5_AirRelease.wav',
#  '9_AirRelease.wav',
#  '6_AirConditioner',
#  '13_AircraftCarrier',
#  '11_AirRegulator',
#  '16_AddingMachine.wav',
#  '16_AirplaneCabin',
#  '16_AirRelease.wav',
#  '12_AirConditioner',
#  '3_AirplaneSingleProp.wav',
#  '5_AirRegulator.wav',
#  '6_AirplaneSingleProp.wav',
#  '1_AirRegulator.wav',
#  '10_AirplaneJet',
#  '16_AirplaneSingleProp.wav',
#  '10_AirplaneCockpit',
#  '1_AirplaneBiplane.wav',
#  '5_AirRelease',
#  '2_AirRelease',
#  '7_AirplaneCockpit',
#  '5_AirplaneCockpit.wav',
#  '4_AirConditioner',
#  '2_AirplaneCockpit',
#  '1_AirRegulator',
#  '9_AirplaneBiplane',
#  '9_AirplaneJet.wav',
#  '16_AirplaneCockpit.wav',
#  '6_AircraftCarrier.wav',
#  '11_AddingMachine',
#  '14_AirConditioner',
#  '11_AirplaneCabin',
#  '2_AirplaneCabin',
#  '7_AirplaneJet',
#  '7_AirplaneBiplane.wav',
#  '5_AirplaneBiplane',
#  '11_AirConditioner',
#  '17_AirplaneCockpit',
#  '8_AirplaneJet',
#  '13_AirplaneSingleProp',
#  '1_AirplaneCockpit',
#  '5_AircraftCarrier',
#  '7_AirplaneBiplane',
#  '6_AirRelease.wav',
#  '12_AddingMachine',
#  '6_AirplaneCabin',
#  '5_AirConditioner',
#  '4_AirplaneCockpit.wav',
#  '15_AirplaneJet.wav',
#  '11_AirRelease',
#  '9_AirplaneSingleProp.wav',
#  '16_AirConditioner.wav',
#  '8_AirplaneCockpit',
#  '6_AirplaneJet.wav',
#  '12_AirplaneSingleProp',
#  '11_AirplaneSingleProp',
#  '7_AirplaneJet.wav',
#  '8_AirConditioner.wav',
#  '12_AirplaneCabin',
#  '12_AirplaneJet',
#  '5_AddingMachine.wav',
#  '4_AirRegulator',
#  '13_AirplaneJet',
#  '15_AirplaneCockpit.wav',
#  '8_AirRelease',
#  '1_AirConditioner.wav',
#  '3_AirplaneJet',
#  '3_AirplaneSingleProp',
#  '3_AirRegulator.wav',
#  '2_AirRegulator',
#  '13_AirplaneBiplane',
#  '17_AirRegulator',
#  '7_AirConditioner.wav',
#  '1_AirplaneSingleProp.wav',
#  '7_AirConditioner',
#  '2_AirplaneCockpit.wav',
#  '16_AirRelease',
#  '12_AirRelease',
#  '13_AirRelease',
#  '8_AddingMachine.wav',
#  '3_AddingMachine',
#  '15_AircraftCarrier.wav',
#  '2_AddingMachine',
#  '1_AirplaneCabin',
#  '5_AirConditioner.wav',
#  '2_AirplaneJet.wav',
#  '4_AirplaneSingleProp',
#  '8_AirplaneBiplane.wav',
#  '8_AirplaneCabin',
#  '4_AirplaneSingleProp.wav',
#  '6_AddingMachine.wav',
#  '1_AirRelease',
#  '9_AirConditioner.wav',
#  '7_AddingMachine',
#  '14_AirRegulator',
#  '6_AirplaneCockpit.wav',
#  '16_AirplaneSingleProp',
#  '3_AirRegulator',
#  '8_AirRegulator',
#  '8_AirplaneCockpit.wav',
#  '16_AirConditioner',
#  '4_AirConditioner.wav',
#  '2_AirRegulator.wav',
#  '17_AirplaneCabin',
#  '8_AirplaneBiplane',
#  '10_AirplaneCabin',
#  '15_AirplaneBiplane',
#  '5_AirRegulator',
#  '1_AircraftCarrier.wav',
#  '15_AirplaneCockpit',
#  '10_AircraftCarrier',
#  '4_AirplaneBiplane',
#  '16_AddingMachine',
#  '10_AirConditioner',
#  '6_AirplaneJet',
#  '16_AirplaneBiplane',
#  '13_AirRegulator',
#  '5_AirplaneCabin.wav',
#  '5_AirplaneJet.wav',
#  '8_AirplaneSingleProp.wav',
#  '16_AirplaneBiplane.wav']

# %%
ipd.Audio(generate_path+'2_AirplaneCockpit.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
